# %%
import pandas as pd
import numpy as np

# %%
air=pd.read_csv("./data/Air_Traffic_Passenger_Statistics.csv")
air.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507        Air Canada                          AC
# 4           200507        Air Canada                          AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3        Air Canada                          AC  International     Canada
# 4        Air Canada                          AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
air.index
# Out:
# RangeIndex(start=0, stop=18398, step=1)

# %%
air.reset_index(inplace=True)
air.set_index(["Operating Airline","Activity Period"],inplace=True)
air.head(10)
# Out:
#                                    level_0  index Operating Airline IATA Code  \
# Operating Airline Activity Period
# ATA Airlines      200507                 0      0                          TZ
#                   200507                 1      1                          TZ
#                   200507                 2      2                          TZ
# Air Canada        200507                 3      3                          AC
#                   200507                 4      4                          AC
# Air China         200507                 5      5                          CA
#                   200507                 6      6                          CA
# Air France        200507                 7      7                          AF
#                   200507                 8      8                          AF
# Air New Zealand   200507                 9      9                          NZ
#
#                                   Published Airline  \
# ...

# %%
print(air.index)
print("******************************************************************************")
print(air.index.get_level_values(0))
print("******************************************************************************")
print(air.index.get_level_values(1))
print("******************************************************************************")
print(air.index.names)
# Out:
# MultiIndex([(    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (    'ATA Airlines', 200507),
#             (      'Air Canada', 200507),
#             (      'Air Canada', 200507),
#             (       'Air China', 200507),
#             (       'Air China', 200507),
#             (      'Air France', 200507),
#             (      'Air France', 200507),
#             ( 'Air New Zealand', 200507),
#             ...
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             (  'Virgin America', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ( 'Virgin Atlantic', 201803),
#             ('Volaris Airlines', 201803),
#             ('Volaris Airlines', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803),
#             (         'WOW Air', 201803)],
#            names=['Operating Airline', 'Activity Period'], length=18398)
# ...

# %%
air.reset_index(inplace=True)
air.head()
# Out:
#   Operating Airline  Activity Period  level_0  index  \
# 0      ATA Airlines           200507        0      0
# 1      ATA Airlines           200507        1      1
# 2      ATA Airlines           200507        2      2
# 3        Air Canada           200507        3      3
# 4        Air Canada           200507        4      4
#
#   Operating Airline IATA Code Published Airline Published Airline IATA Code  \
# 0                          TZ      ATA Airlines                          TZ
# 1                          TZ      ATA Airlines                          TZ
# 2                          TZ      ATA Airlines                          TZ
# 3                          AC        Air Canada                          AC
# 4                          AC        Air Canada                          AC
#
#      GEO Summary GEO Region Activity Type Code Price Category Code  \
# 0       Domestic         US           Deplaned            Low Fare
# ...

# %%
air.set_index(["Activity Period","Operating Airline"],inplace=True)
air.head(10)
# Out:
#                                    level_0  index Operating Airline IATA Code  \
# Activity Period Operating Airline
# 200507          ATA Airlines             0      0                          TZ
#                 ATA Airlines             1      1                          TZ
#                 ATA Airlines             2      2                          TZ
#                 Air Canada               3      3                          AC
#                 Air Canada               4      4                          AC
#                 Air China                5      5                          CA
#                 Air China                6      6                          CA
#                 Air France               7      7                          AF
#                 Air France               8      8                          AF
#                 Air New Zealand          9      9                          NZ
#
#                                   Published Airline  \
# ...

# %%
print(air.index)
print("******************************************************************************")
print(air.index.get_level_values(0))
print("******************************************************************************")
print(air.index.get_level_values(1))
print("******************************************************************************")
print(air.index.names)
# Out:
# MultiIndex([(200507,     'ATA Airlines'),
#             (200507,     'ATA Airlines'),
#             (200507,     'ATA Airlines'),
#             (200507,       'Air Canada'),
#             (200507,       'Air Canada'),
#             (200507,        'Air China'),
#             (200507,        'Air China'),
#             (200507,       'Air France'),
#             (200507,       'Air France'),
#             (200507,  'Air New Zealand'),
#             ...
#             (201803,   'Virgin America'),
#             (201803,   'Virgin America'),
#             (201803,   'Virgin America'),
#             (201803,  'Virgin Atlantic'),
#             (201803,  'Virgin Atlantic'),
#             (201803, 'Volaris Airlines'),
#             (201803, 'Volaris Airlines'),
#             (201803,          'WOW Air'),
#             (201803,          'WOW Air'),
#             (201803,          'WOW Air')],
#            names=['Activity Period', 'Operating Airline'], length=18398)
# ...
