# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv("./data/weather_barcelona.csv",index_col="Date")

# %%
rom = pd.read_csv("./data/weather_rome.csv",index_col="Date")

# %%
ams = pd.read_csv("./data/weather_amsterdam.csv",index_col="Date")

# %%
tempMax=pd.DataFrame(index=bar.index)

# %%
tempMax["Barcelona"]=bar["TempMax"]
tempMax["Rome"]=rom["TempMax"]
tempMax["Amstredam"]=ams["TempMax"]

# %%
def gradeDay(row):
    if (row["TempMax"] >= row["AvgTempMax"]):
        return "PLUS"
    else:
        return "MINUS"

# %%
rom["gradeDay"] = rom.apply(gradeDay,axis=1)
bar["gradeDay"] = bar.apply(gradeDay,axis=1)
ams["gradeDay"] = ams.apply(gradeDay,axis=1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin gradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom["gradeDay"].value_counts()
# Out:
# PLUS     70
# MINUS    20
# Name: gradeDay, dtype: int64

# %%
cities3 = pd.DataFrame(index=["MINUS","PLUS"])

# %%
cities3["Barcelona"] = bar["gradeDay"].value_counts()

# %%
cities3["Rome"] = rom["gradeDay"].value_counts()

# %%
cities3["Amsterdam"] = ams["gradeDay"].value_counts()

# %%
cities3
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3["Barcelona"].plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Barcelona'>

# %%
cities3["Barcelona"].plot(kind="pie",figsize=(7,7))
# Out:
# <AxesSubplot:ylabel='Barcelona'>

# %%
cities3.plot(kind="pie",subplots=True,figsize=(21,7))
# Out:
# array([<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>,
#        <AxesSubplot:ylabel='Amsterdam'>], dtype=object)

# %%
cities3.plot(kind="pie",subplots=True,figsize=(21,7),colors=["b","g"])
# Out:
# array([<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>,
#        <AxesSubplot:ylabel='Amsterdam'>], dtype=object)

# %%
cities3.plot(kind="pie",subplots=True,figsize=(21,7),colors=["b","g"],labels=["colder","warmer"])
# Out:
# array([<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>,
#        <AxesSubplot:ylabel='Amsterdam'>], dtype=object)

# %%
cities3.plot(kind="pie",subplots=True,figsize=(21,7),colors=["b","g"],labels=["colder","warmer"],
            autopct="%.1f%%",fontsize=20, textprops=dict(color="w"))
# Out:
# array([<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>,
#        <AxesSubplot:ylabel='Amsterdam'>], dtype=object)

# %%
cities3.plot(kind="pie",subplots=True,figsize=(10,10),colors=["b","g"],labels=["colder","warmer"],
            autopct="%.1f%%",fontsize=20, textprops=dict(color="w"),layout=(2,2))
# Out:
# array([[<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>],
#        [<AxesSubplot:ylabel='Amsterdam'>, <AxesSubplot:>]], dtype=object)

# %%
cities3.plot(kind="pie",subplots=True,figsize=(10,10),colors=["b","g"],labels=["colder","warmer"],
            autopct="%.1f%%",fontsize=15, textprops=dict(color="w"),explode=(0.1,0))
# Out:
# array([<AxesSubplot:ylabel='Barcelona'>, <AxesSubplot:ylabel='Rome'>,
#        <AxesSubplot:ylabel='Amsterdam'>], dtype=object)
